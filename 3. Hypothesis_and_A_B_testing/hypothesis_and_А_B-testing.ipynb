# %% [markdown]
# # Принятие решений в бизнесе

# %% [markdown]
# **Описание проекта**

# %% [markdown]
# Необходимо провести приоритизацию списка гипотез, подготовленных вместе с отделом маркетинга интернет-магазина для увеличения выручки (первая часть), а также запустить A/B-тест и проанализировать результаты (вторая часть).

# %% [markdown]
# **Описание данных**

# %% [markdown]
# ***Данные для первой части***

# %% [markdown]
# Файл `/datasets/hypothesis.csv`
# * `Hypothesis` — краткое описание гипотезы;
#
# * `Reach` — охват пользователей по 10-балльной шкале;
#
# * `Impact` — влияние на пользователей по 10-балльной шкале;
#
# * `Confidence` — уверенность в гипотезе по 10-балльной шкале;
#
# * `Efforts` — затраты ресурсов на проверку гипотезы по 10-балльной шкале. Чем больше значение `Efforts`, тем дороже проверка гипотезы.

# %% [markdown]
# ***Данные для второй части***

# %% [markdown]
# Файл `/datasets/orders.csv`
# * `transactionId` — идентификатор заказа;
#
# * `visitorId` — идентификатор пользователя, совершившего заказ;
#
# * `date` — дата, когда был совершён заказ;
#
# * `revenue` — выручка заказа;
#
# * `group` — группа A/B-теста, в которую попал заказ.
#
# Файл `/datasets/visitors.csv`
# * `date` — дата;
#
# * `group` — группа A/B-теста;
#
# * `visitors` — количество пользователей в указанную дату в указанной группе A/B-теста.

# %% [markdown]
# **План работы**

# %% [markdown]
# ***1. Загрузка и подготовка данных к анализу.***

# %% [markdown]
# 1.1. Вывод основной информацию о данных.
# 1.2. Предобработка данных.

# %% [markdown]
# ***2. Приоритизация гипотез (Часть 1).***

# %% [markdown]
# 2.1. Применим фреймворк ICE для приоритизации гипотез. Отсортируем их по убыванию приоритета.
# 2.2. Применим фреймворк RICE для приоритизации гипотез. Отсортируем их по убыванию приоритета.
# 2.3. Проверим, как изменилась приоритизация гипотез при применении RICE вместо ICE.

# %% [markdown]
# ***3. Анализ A/B-теста (Часть 2).***

# %% [markdown]
# 3.1. Построим график кумулятивной выручки по группам.
# 3.2. Построим график кумулятивного среднего чека по группам.
# 3.3. Построим график относительного изменения кумулятивного среднего чека группы B к группе A.
# 3.4. Построим график кумулятивного среднего количества заказов на посетителя по группам.
# 3.5. Построим график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A.
# 3.6. Построим точечный график количества заказов по пользователям.
# 3.7. Посчитаем 95-й и 99-й перцентили количества заказов на пользователя. Выберем границу для определения аномальных пользователей.
# 3.8. Построим точечный график стоимостей заказов.
# 3.9. Посчитаем 95-й и 99-й перцентили стоимости заказов. Выберем границу для определения аномальных заказов.
# 3.10. Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным.
# 3.11. Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным.
# 3.12. Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным.
# 3.13. Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным.
# 3.14. Примем решение по результатам теста и объясним его.

# %% [markdown]
# ***4. Выводы.***

# %% [markdown]
# **Навыки и инструменты**

# %% [markdown]
# `Python`
# `Pandas`
# `Matplotlib`
# `SciPy`
#
# `A/B-тестирование`
# `Проверка статистических гипотез`

# %% [markdown]
# **Вывод**

# %% [markdown]
# По 1-й части (приоритизация гипотез):
# * Приоритизация гипотез методами "ICE" и "RICE" даёт немного разные списки перспективных гипотез. Наиболее перспективная гипотеза по методу "RICE" с учётом охвата максимального количества пользователей - гипотеза №7: "Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок".
#
# По 2-й части (анализ результатов А/В-теста):
# * По "очищенным" и по "сырым" данным есть различие в среднем количестве заказов на посетителя между группами "A" и "B", относительный выигрыш группы "B" над "A" по "очищенным" данным - 15.3%.
# * Различия по среднему чеку между группами "А" и "В" нет, средний чек по "очищенным" данным меньше у группы "В" на -0.6%.
# Исходя из обнаруженных фактов, следует остановить тест, зафиксировать победу группы "В".

# %% [markdown]
# <h1>Содержания<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-и-подготовка-данных-к-анализу." data-toc-modified-id="Загрузка-и-подготовка-данных-к-анализу.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка и подготовка данных к анализу.</a></span><ul class="toc-item"><li><span><a href="#Вывод-основной-информацию-о-данных." data-toc-modified-id="Вывод-основной-информацию-о-данных.-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод основной информацию о данных.</a></span><ul class="toc-item"><li><span><a href="#Выведем-информацию-о-данных-таблицы-hypothesis." data-toc-modified-id="Выведем-информацию-о-данных-таблицы-hypothesis.-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Выведем информацию о данных таблицы <code>hypothesis</code>.</a></span></li><li><span><a href="#Выведем-информацию-о-данных-таблицы-orders." data-toc-modified-id="Выведем-информацию-о-данных-таблицы-orders.-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Выведем информацию о данных таблицы <code>orders</code>.</a></span></li><li><span><a href="#Выведем-информацию-о-данных-таблицы-visitors." data-toc-modified-id="Выведем-информацию-о-данных-таблицы-visitors.-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Выведем информацию о данных таблицы <code>visitors</code>.</a></span></li></ul></li><li><span><a href="#Предобработка-данных." data-toc-modified-id="Предобработка-данных.-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Предобработка данных.</a></span><ul class="toc-item"><li><span><a href="#Замена-названий-столбцов-(приведение-к-&quot;нижнему-регистру&quot;-и-&quot;змеиному_регистру&quot;)-в-таблицах." data-toc-modified-id="Замена-названий-столбцов-(приведение-к-&quot;нижнему-регистру&quot;-и-&quot;змеиному_регистру&quot;)-в-таблицах.-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Замена названий столбцов (приведение к "нижнему регистру" и "змеиному_регистру") в таблицах.</a></span></li><li><span><a href="#Преобразование-типа-данных-в-таблицах." data-toc-modified-id="Преобразование-типа-данных-в-таблицах.-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Преобразование типа данных в таблицах.</a></span></li></ul></li></ul></li><li><span><a href="#Приоритизация-гипотез-(Часть-1)." data-toc-modified-id="Приоритизация-гипотез-(Часть-1).-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Приоритизация гипотез (Часть 1).</a></span><ul class="toc-item"><li><span><a href="#Применим-фреймворк-ICE-для-приоритизации-гипотез.-Отсортируем-их-по-убыванию-приоритета." data-toc-modified-id="Применим-фреймворк-ICE-для-приоритизации-гипотез.-Отсортируем-их-по-убыванию-приоритета.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Применим фреймворк ICE для приоритизации гипотез. Отсортируем их по убыванию приоритета.</a></span></li><li><span><a href="#Применим-фреймворк-RICE-для-приоритизации-гипотез.-Отсортируем-их-по-убыванию-приоритета." data-toc-modified-id="Применим-фреймворк-RICE-для-приоритизации-гипотез.-Отсортируем-их-по-убыванию-приоритета.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Применим фреймворк RICE для приоритизации гипотез. Отсортируем их по убыванию приоритета.</a></span></li><li><span><a href="#Проверим,-как-изменилась-приоритизация-гипотез-при-применении-RICE-вместо-ICE." data-toc-modified-id="Проверим,-как-изменилась-приоритизация-гипотез-при-применении-RICE-вместо-ICE.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Проверим, как изменилась приоритизация гипотез при применении RICE вместо ICE.</a></span></li></ul></li><li><span><a href="#Анализ-A/B-теста-(Часть-2)." data-toc-modified-id="Анализ-A/B-теста-(Часть-2).-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ A/B-теста (Часть 2).</a></span><ul class="toc-item"><li><span><a href="#Построим-график-кумулятивной-выручки-по-группам." data-toc-modified-id="Построим-график-кумулятивной-выручки-по-группам.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Построим график кумулятивной выручки по группам.</a></span></li><li><span><a href="#Построим-график-кумулятивного-среднего-чека-по-группам." data-toc-modified-id="Построим-график-кумулятивного-среднего-чека-по-группам.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Построим график кумулятивного среднего чека по группам.</a></span></li><li><span><a href="#Построим-график-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A." data-toc-modified-id="Построим-график-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Построим график относительного изменения кумулятивного среднего чека группы B к группе A.</a></span></li><li><span><a href="#Построим-график-кумулятивного-среднего-количества-заказов-на-посетителя-по-группам." data-toc-modified-id="Построим-график-кумулятивного-среднего-количества-заказов-на-посетителя-по-группам.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Построим график кумулятивного среднего количества заказов на посетителя по группам.</a></span></li><li><span><a href="#Построим-график-относительного-изменения-кумулятивного-среднего-количества-заказов-на-посетителя-группы-B-к-группе-A." data-toc-modified-id="Построим-график-относительного-изменения-кумулятивного-среднего-количества-заказов-на-посетителя-группы-B-к-группе-A.-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Построим график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A.</a></span></li><li><span><a href="#Построим-точечный-график-количества-заказов-по-пользователям." data-toc-modified-id="Построим-точечный-график-количества-заказов-по-пользователям.-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Построим точечный график количества заказов по пользователям.</a></span></li><li><span><a href="#Посчитаем-95-й-и-99-й-перцентили-количества-заказов-на-пользователя.-Выберем-границу-для-определения-аномальных-пользователей." data-toc-modified-id="Посчитаем-95-й-и-99-й-перцентили-количества-заказов-на-пользователя.-Выберем-границу-для-определения-аномальных-пользователей.-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Посчитаем 95-й и 99-й перцентили количества заказов на пользователя. Выберем границу для определения аномальных пользователей.</a></span></li><li><span><a href="#Построим-точечный-график-стоимостей-заказов." data-toc-modified-id="Построим-точечный-график-стоимостей-заказов.-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Построим точечный график стоимостей заказов.</a></span></li><li><span><a href="#Посчитаем-95-й-и-99-й-перцентили-стоимости-заказов.-Выберем-границу-для-определения-аномальных-заказов." data-toc-modified-id="Посчитаем-95-й-и-99-й-перцентили-стоимости-заказов.-Выберем-границу-для-определения-аномальных-заказов.-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Посчитаем 95-й и 99-й перцентили стоимости заказов. Выберем границу для определения аномальных заказов.</a></span></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«сырым»-данным." data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«сырым»-данным.-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным.</a></span></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным." data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным.-3.11"><span class="toc-item-num">3.11&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным.</a></span></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«очищенным»-данным." data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«очищенным»-данным.-3.12"><span class="toc-item-num">3.12&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным.</a></span></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным." data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным.-3.13"><span class="toc-item-num">3.13&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным.</a></span></li><li><span><a href="#Примем-решение-по-результатам-теста-и-объясним-его." data-toc-modified-id="Примем-решение-по-результатам-теста-и-объясним-его.-3.14"><span class="toc-item-num">3.14&nbsp;&nbsp;</span>Примем решение по результатам теста и объясним его.</a></span></li></ul></li><li><span><a href="#Выводы." data-toc-modified-id="Выводы.-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Выводы.</a></span></li></ul></div>

# %% [markdown]
# _________

# %% [markdown]
# ## Загрузка и подготовка данных к анализу.

# %% [markdown]
# ### Вывод основной информацию о данных.

# %% [markdown]
# Загрузим данные из CSV-файлов в переменные.
# Изучим данные, проверим есть ли в данных пропуски и дубликаты. Убедимся, что типы
# данных во всех колонках соответствуют сохранённым в них значениям.

# %%
# импортируем библиотеки
import pandas as pd
import scipy.stats as stats
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
import warnings
# конвертеры, которые позволяют использовать типы pandas в matplotlib  
register_matplotlib_converters()

# %%
# cчитаем данные из csv-файлов и сохраним в переменные "hypothesis", "orders", "visitors"
try:
    hypothesis, orders, visitors = (
        pd.read_csv('/datasets/hypothesis.csv'),
        pd.read_csv('/datasets/orders.csv'),
        pd.read_csv('/datasets/visitors.csv')
    )
except:
    hypothesis, orders, visitors = (
        pd.read_csv('hypothesis.csv'),
        pd.read_csv('orders.csv'),
        pd.read_csv('visitors.csv')
    )

# %%
# сбрасываем ограничение на количество символов в записе
pd.set_option('display.max_colwidth', None)

# %%
# используем функцию для вывода информации о данных, статистических показателях, количестве пропусков и дубликатов
def data_view(df, df_name):
    df.name = df_name
    print(' ')
    print(f'Первые 5 строк таблицы "{df.name}":')
    display(df.head())
    print(' ')
    print(f'Основная информация о таблице "{df.name}":')
    print(' ')
    df.info()
    print(' ')
    print(f'Статистические показатели данных в столбцах таблицы "{df.name}":')
    display(df.describe())
    print(' ')
    print(f'Количество пропусков в таблице "{df.name}":')
    print(' ')
    print(df.isna().sum())
    print(' ')
    print(f'Количество дубликатов в таблице "{df.name}": {df.duplicated().sum()}')

# %% [markdown]
# #### Выведем информацию о данных таблицы `hypothesis`.

# %%
data_view(hypothesis, 'hypothesis')
# Out:
#
# Первые 5 строк таблицы "hypothesis":
#                                                                                                      Hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
#
#    Reach  Impact  Confidence  Efforts
# 0      3      10           8        6
# 1      2       5           4       10
# 2      8       3           7        3
# 3      8       3           3        8
# 4      3       1           1        1
#
# ...

# %% [markdown]
# В таблице **`hypothesis`** - 9 строк, 5 столбцов. В каждой строке информация о гипотезе (краткое описание, охват пользователей, влияние на пользователей, уверенность в гипотезе, затраты ресурсов на проверку гипотезы).
#
# Содержание данных:
# * `Hypothesis` — краткое описание гипотезы;
# * `Reach` — охват пользователей по 10-балльной шкале;
# * `Impact` — влияние на пользователей по 10-балльной шкале;
# * `Confidence` — уверенность в гипотезе по 10-балльной шкале;
# * `Efforts` — затраты ресурсов на проверку гипотезы по 10-балльной шкале. Чем больше значение Efforts, тем дороже проверка гипотезы.
#
# Типы данных столбцов — **object** и **int64**. В таблице нет пропусков и дубликатов. Числовые значения столбцов `Reach`, `Impact`, `Confidence` и `Efforts` соответствуют 10-балльной шкале: минимальное значение - 1, максимальное значение - 10.
#
# Необходимо:
# - исправить название столбцов в соответствии с хорошим стилем (привести к "нижнему регистру").

# %% [markdown]
# #### Выведем информацию о данных таблицы `orders`.

# %%
data_view(orders, 'orders')
# Out:
#
# Первые 5 строк таблицы "orders":
#    transactionId   visitorId        date  revenue group
# 0     3667963787  3312258926  2019-08-15     1650     B
# 1     2804400009  3642806036  2019-08-15      730     B
# 2     2961555356  4069496402  2019-08-15      400     A
# 3     3797467345  1196621759  2019-08-15     9759     B
# 4     2282983706  2322279887  2019-08-15     2308     B
#
# Основная информация о таблице "orders":
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  1197 non-null   int64
#  1   visitorId      1197 non-null   int64
#  2   date           1197 non-null   object
#  3   revenue        1197 non-null   int64
#  4   group          1197 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 46.9+ KB
#
# Статистические показатели данных в столбцах таблицы "orders":
# ...

# %%
# проверим минимальную и максимальную дату заказа в столбце 'date'
print("Минимальная дата в столбце 'date':'", orders['date'].min())
print("Максимальная дата в столбце 'date':'", orders['date'].max())
# Out:
# Минимальная дата в столбце 'date':' 2019-08-01
# Максимальная дата в столбце 'date':' 2019-08-31

# %% [markdown]
# Минимальная дата меньше максимальной даты, всё верно.

# %% [markdown]
# Проверим количество уникальных пользователей, совершивших заказ, в каждой из групп А/В-теста.

# %%
print('')
print('Количество уникальных пользователей, совершивших заказ, в каждой из групп А/В-теста:')
visitors_ab = orders.groupby('group', as_index=False).agg({'visitorId': 'nunique'})
display(visitors_ab)
print('Общее количество уникальных пользователей, совершивших заказ, в группах "А" и "В":', visitors_ab['visitorId'].sum())
visitors_total = orders['visitorId'].nunique()
print('Общее количество уникальных пользователей, совершивших заказ, в таблице "orders":', visitors_total)
# Out:
# Количество уникальных пользователей, совершивших заказ, в каждой из групп А/В-теста:
#   group  visitorId
# 0     A        503
# 1     B        586
# Общее количество уникальных пользователей, совершивших заказ, в группах "А" и "В": 1089
# Общее количество уникальных пользователей, совершивших заказ, в таблице "orders": 1031

# %%
# проверим, сколько пользователей попали одновременно в обе группы
orders.groupby('visitorId').agg({'group' : 'nunique'}).query('group > 1').count()
# Out:
# group    58
# dtype: int64

# %% [markdown]
# Количество уникальных пользователей, совершивших заказ, в группе "A" и группе "B" разное и отличается ~ на 16.5%. Один из критериев проведения успешного А/А-теста (проводится перед тем как провести А/В-тест) - количество пользователей в различных группах должно различаться не более, чем на 1%.
# 58 пользователей попали одновременно и в группу "A" и группу "B". Результаты теста для этих пользователей нельзя интерпретировать однозначно, правильным было бы исключить этих пользователей из анализа или рассмотреть вопрос о перезапуске теста. Но пока оставим, как есть.

# %% [markdown]
# В таблице **`orders`** - 1197 строк, 5 столбцов. В каждой строке информация о заказе (идентификатор заказа, идентификатор пользователя, дата заказа, выручка заказа, группа А/В-теста) в период с 01.08.2019. по 31.08.2019.
#
# Содержание данных:
# * `transactionId` — идентификатор заказа;
# * `visitorId` — идентификатор пользователя, совершившего заказ;
# * `date` — дата, когда был совершён заказ;
# * `revenue` — выручка заказа;
# * `group` — группа A/B-теста, в которую попал заказ.
#
# Типы данных столбцов — **object** и **int64**. В таблице нет пропусков и дубликатов. Числовые значения столбца `revenue`> 0.
#
# Необходимо:
# - исправить название столбцов `transactionId` и `visitorId` в соответствии с хорошим стилем (привести к "нижнему регистру" и "змеиному_регистру").
# - преобразовать тип данных столбца с датой `date` в datetime.

# %% [markdown]
# #### Выведем информацию о данных таблицы `visitors`.

# %%
data_view(visitors, 'visitors')
# Out:
#
# Первые 5 строк таблицы "visitors":
#          date group  visitors
# 0  2019-08-01     A       719
# 1  2019-08-02     A       619
# 2  2019-08-03     A       507
# 3  2019-08-04     A       717
# 4  2019-08-05     A       756
#
# Основная информация о таблице "visitors":
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      62 non-null     object
#  1   group     62 non-null     object
#  2   visitors  62 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.6+ KB
#
# Статистические показатели данных в столбцах таблицы "visitors":
#          visitors
# count   62.000000
# mean   607.290323
# std    114.400560
# min    361.000000
# 25%    534.000000
# 50%    624.500000
# 75%    710.500000
# max    770.000000
#
# Количество пропусков в таблице "visitors":
#
# date        0
# group       0
# visitors    0
# dtype: int64
#
# ...

# %%
# проверим минимальнцю и максимальную дату в столбце 'date'
print("Минимальная дата в столбце 'date':'", visitors['date'].min())
print("Максимальная дата в столбце 'date':'", visitors['date'].max())
# Out:
# Минимальная дата в столбце 'date':' 2019-08-01
# Максимальная дата в столбце 'date':' 2019-08-31

# %% [markdown]
# Минимальная дата меньше максимальной даты, всё верно.

# %% [markdown]
# В таблице **`visitors`** - 62 строки, 3 столбца. В каждой строке информация о количестве пользователей в группе А или группе В А/В-теста на определенную дату (дата, группа A/B-теста, количество пользователей) в период с 01.08.2019. по 31.08.2019.
#
# Содержание данных:
# * `date` — дата;
# * `group` — группа A/B-теста;
# * `visitors` — количество пользователей в указанную дату в указанной группе A/B-теста.
#
# Типы данных столбцов — **object** и **int64**. В таблице нет пропусков и дубликатов. Числовые значения столбца `visitors`> 0.
#
# Необходимо:
# - преобразовать тип данных столбца с датой `date` в datetime.

# %% [markdown]
# ### Предобработка данных.

# %% [markdown]
# #### Замена названий столбцов (приведение к "нижнему регистру" и "змеиному_регистру") в таблицах.

# %%
# приведём названия столбцов таблицы 'hypothesis' к "нижнему регистру"
hypothesis.columns = hypothesis.columns.str.lower()
hypothesis.columns
# Out:
# Index(['hypothesis', 'reach', 'impact', 'confidence', 'efforts'], dtype='object')

# %%
# переименуем названия столбцов 'transactionId' и 'visitorId' таблицы 'orders' в соответствии со змеиным_регистром
orders.rename(columns={'transactionId': 'transaction_id', 'visitorId': 'visitor_id'}, inplace=True)
orders.columns
# Out:
# Index(['transaction_id', 'visitor_id', 'date', 'revenue', 'group'], dtype='object')

# %% [markdown]
# Названия столбцов в таблицах `hypothesis` и `orders` исправлены (приведены к "нижнему регистру" и "змеиному_регистру").

# %% [markdown]
# #### Преобразование типа данных в таблицах.

# %%
# преобразуем тип данных столбцов с датой в "datetime" в таблицах 'orders' и 'visitors'
orders['date'] = pd.to_datetime(orders['date'])
visitors['date'] = pd.to_datetime(visitors['date'])

# %% [markdown]
# Проверим преобразование типа данных в столбцах таблиц `orders` и `visitors`.

# %%
orders.dtypes
# Out:
# transaction_id             int64
# visitor_id                 int64
# date              datetime64[ns]
# revenue                    int64
# group                     object
# dtype: object

# %%
visitors.dtypes
# Out:
# date        datetime64[ns]
# group               object
# visitors             int64
# dtype: object

# %% [markdown]
# Типы данных столбцов с датой в таблицах `orders`, `visitors` преобразован в "datetime".

# %% [markdown]
# **Вывод**
#
# Мы изучили данные и выполнили предобработку. Проверили пропуски и дубликаты в данных. Проверили, чтобы типы данных во всех столбцах соответствовали сохранённым в них значениям.
# Пропуски и дубликаты в данных отсутствуют. Название столбцов в таблицах были исправлены в соответствии с хорошим стилем (приведены к "нижнему регистру" и "змеиному_регистру"). Тип данных в столбцах с датой был преобразован в "datetime". Диапазон дат в таблицах `orders` и `visitors` совпадает (с 01.08.2019. по 31.08.2019.).

# %% [markdown]
# ## Приоритизация гипотез (Часть 1).

# %% [markdown]
# ### Применим фреймворк ICE для приоритизации гипотез. Отсортируем их по убыванию приоритета.

# %%
# выведем таблицу 'hypothesis'
hypothesis
# Out:
#                                                                                                      hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# ...

# %% [markdown]
# Посчитаем **"ICE"** для гипотез. Выведем столбцы 'hypothesis' и 'ICE', отсортированные по столбцу 'ICE'.

# %%
hypothesis['ICE'] = (hypothesis['impact'] * hypothesis['confidence']) / hypothesis['efforts']
hypothesis.sort_values(by='ICE', ascending= False)[['hypothesis', 'ICE']]
# Out:
#                                                                                                      hypothesis  \
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# ...

# %% [markdown]
# Наиболее перспективные гипотезы по методу **"ICE"**:
# * Запустить акцию, дающую скидку на товар в день рождения (№ 8).
# * Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей (№ 0).
# * Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок (№ 7).

# %% [markdown]
# ### Применим фреймворк RICE для приоритизации гипотез. Отсортируем их по убыванию приоритета.

# %% [markdown]
# Посчитаем **"RICE"** для гипотез. Выведем столбцы 'hypothesis' и 'RICE', отсортированные по столбцу 'RICE'.

# %%
hypothesis['RICE'] = (hypothesis['reach'] * hypothesis['impact'] * hypothesis['confidence']) / hypothesis['efforts']
hypothesis.sort_values(by='RICE', ascending= False)[['hypothesis', 'RICE']]
# Out:
#                                                                                                      hypothesis  \
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# ...

# %% [markdown]
# Наиболее перспективные гипотезы по методу **"RICE"**:
# * Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок (№ 7).
# * Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа (№ 2).
# * Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей (№ 0).
# * Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию (№ 6).

# %% [markdown]
# ### Проверим, как изменилась приоритизация гипотез при применении RICE вместо ICE.

# %% [markdown]
# При использовании метода **"RICE"** вместо **"ICE"** приоритизация гипотез изменилась. На первом месте гипотеза под номером 7: ***Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок***. Так получилось, потому что у неё параметр `reach` равен максимальному значению - 10, в то время, как у других гипотез этот параметр меньше. А также у этой гипотезы высокие параметры `impact` и `confidence`. Кроме влияния и уверенности у этой гипотезы самый большой охват пользователей.

# %% [markdown]
# **Вывод**
#
# Приоритизация гипотез методами **"ICE"** и **"RICE"** даёт немного разные списки перспективных гипотез.
# Наиболее перспективная гипотеза по методу **"RICE"** с учётом охвата максимального количества пользователей - гипотеза №7: ***Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок***. Для проведения тестирования эта гипотеза будет самой приоритетной.

# %% [markdown]
# ## Анализ A/B-теста (Часть 2).

# %% [markdown]
# Проанализируем результаты А/В-теста на основе данных в таблицах `orders` и `visitors`.

# %% [markdown]
# ### Построим график кумулятивной выручки по группам.

# %%
# выведем первые 5 строк таблицы 'orders'
orders.head()
# Out:
#    transaction_id  visitor_id       date  revenue group
# 0      3667963787  3312258926 2019-08-15     1650     B
# 1      2804400009  3642806036 2019-08-15      730     B
# 2      2961555356  4069496402 2019-08-15      400     A
# 3      3797467345  1196621759 2019-08-15     9759     B
# 4      2282983706  2322279887 2019-08-15     2308     B

# %%
# создаем массив уникальных пар значений дат и групп теста
datesGroups = orders[['date','group']].drop_duplicates()

# %%
# cоберём агрегированные кумулятивные по дням данные о заказах
ordersAggregated = datesGroups.apply(
    lambda x: orders[
        np.logical_and(
            orders['date'] <= x['date'], orders['group'] == x['group']
        )
    ].agg(
        {
            'date': 'max',
            'group': 'max',
            'transaction_id': 'nunique',
            'visitor_id': 'nunique',
            'revenue': 'sum'
        }
    ),
    axis=1
).sort_values(by=['date', 'group'])

# %%
# выведем первые 5 строк таблицы 'visitors'
visitors.head()
# Out:
#         date group  visitors
# 0 2019-08-01     A       719
# 1 2019-08-02     A       619
# 2 2019-08-03     A       507
# 3 2019-08-04     A       717
# 4 2019-08-05     A       756

# %%
# получим агрегированные кумулятивные по дням данные о посетителях 
visitorsAggregated = datesGroups.apply(
    lambda x: visitors[
        np.logical_and(
            visitors['date'] <= x['date'], visitors['group'] == x['group']
        )
    ].agg({'date': 'max', 'group': 'max', 'visitors': 'sum'}),
    axis=1
).sort_values(by=['date', 'group'])

# %%
# объеденим кумулятивные данные в одной таблице и присвоим ее столбцам новые названия
cumulativeData = ordersAggregated.merge(
    visitorsAggregated, left_on=['date', 'group'], right_on=['date', 'group']
)
cumulativeData.columns = [
    'date',
    'group',
    'orders',
    'buyers',
    'revenue',
    'visitors',
]

# %%
# создадим датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А
cumulativeRevenueA = cumulativeData[cumulativeData['group']=='A'][['date','revenue', 'orders']]

# создадим датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе B
cumulativeRevenueB = cumulativeData[cumulativeData['group']=='B'][['date','revenue', 'orders']]

# %% [markdown]
# Построим график кумулятивной выручки по группам.

# %%
# изменим размер фигуры
plt.figure(figsize=(8, 5))

# построим график выручки группы А
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'], label='A')

# построим график выручки группы B
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'], label='B')

plt.title('График кумулятивной выручки по группам')
plt.xlabel('Дата')
plt.xticks(rotation=45)
plt.ylabel('Выручка')
plt.grid()
plt.legend();

# %% [markdown]
# На графике видно, что до 5-го августа выручка в группах примерно одинаковая, с 5-го по 13-ое августа выручка в группе "В" растёт быстрее чем в группе "А", но 13-го августа выручки опять сравниваются. После 13-го августа выручка в группе "В" опять растёт быстрее чем в группе "А" и к 1-му сентября примерно в 1,5 раза больше чем в группе "А". Стоит отметить сильный рост выручки в группе "В" 19-го августа, который может быть вызван резким увеличением количества заказов, либо суммы заказов, либо того и другого одновременно. Без учёта этого сильного роста графики группы "А" и "В" растут примерно одинаково с 19-го августа.

# %% [markdown]
# ### Построим график кумулятивного среднего чека по группам.

# %% [markdown]
# Построим графики среднего чека по группам — разделим кумулятивную выручку на кумулятивное число заказов.

# %%
# изменим размер фигуры
plt.figure(figsize=(8, 5))

# построим график кумулятивного среднего чека группы А
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue']/cumulativeRevenueA['orders'], label='A')

# построим график кумулятивного среднего чека группы B
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue']/cumulativeRevenueB['orders'], label='B')

plt.title('График кумулятивного среднего чека по группам')
plt.xlabel('Дата')
plt.xticks(rotation=45)
plt.ylabel('Средний чек')
plt.grid()
plt.legend();

# %% [markdown]
# На графике видно, что средний чек групп попеременно то растёт, то снижается. Средний чек группы "A" резко снижается с 1-го по 6-ое августа, затем резко растёт до 13-го августа, после чего опять снижается, но незначительно и после 14-го августа устанавливается примерно на одном уровне до 28-го августа. Средний чек группы "B" скачкообразно растёт до 19-го августа, причём, как и на графике кумулятивной выручки по группам виден резкий скачок 19-го августа (~ 1,5 раза), после чего средний чек группы "В" начинает снижаться.

# %% [markdown]
# ### Построим график относительного изменения кумулятивного среднего чека группы B к группе A.

# %%
# собираем данные в одном датафрейме
mergedCumulativeRevenue = cumulativeRevenueA.merge(cumulativeRevenueB, left_on='date', right_on='date', how='left',\
                                                   suffixes=['A', 'B'])

# изменим размер фигуры
plt.figure(figsize=(8, 5))

# cтроим отношение средних чеков группы B к группе A
plt.plot(mergedCumulativeRevenue['date'], (mergedCumulativeRevenue['revenueB']/mergedCumulativeRevenue['ordersB'])\
         /(mergedCumulativeRevenue['revenueA']/mergedCumulativeRevenue['ordersA'])-1)

# добавляем ось X
plt.axhline(y=0, color='black', linestyle='--')

plt.title('График относительного изменения кумулятивного среднего чека группы B к группе A')
plt.xlabel('Дата')
plt.xticks(rotation=45)
plt.ylabel('Отношение среднего чека группы B к группе A')
plt.grid();

# %% [markdown]
# В нескольких точках график различия между группами резко «скачет». Самый большой скачок как и на предыдущих графиках - 19-го августа. Видимо в эти даты были совершенны крупные заказы и выбросы.

# %% [markdown]
# ### Построим график кумулятивного среднего количества заказов на посетителя по группам.

# %% [markdown]
# Построим график кумулятивной конверсии (отношения кумулятивного среднего количества заказов к количеству посетителей) по дням по группам.

# %%
# считаем кумулятивную конверсию
cumulativeData['conversion'] = cumulativeData['orders']/cumulativeData['visitors']

# отделяем данные по группе A
cumulativeDataA = cumulativeData[cumulativeData['group']=='A']

# отделяем данные по группе B
cumulativeDataB = cumulativeData[cumulativeData['group']=='B']

# изменим размер фигуры
plt.figure(figsize=(8, 5))

# строим графики
plt.plot(cumulativeDataA['date'], cumulativeDataA['conversion'], label='A')
plt.plot(cumulativeDataB['date'], cumulativeDataB['conversion'], label='B')
plt.legend()

# задаем масштаб осей
plt.axis(['2019-08-01', '2019-09-01', 0.028, 0.038])

plt.title('График кумулятивного среднего количества заказов на посетителя по группам')
plt.xlabel('Дата')
plt.xticks(rotation=45)
plt.ylabel('Конверсия')
plt.grid();

# %% [markdown]
# В начале теста группа "А" имела большее количество заказов, 6-го августа конверсия групп сравнялась, а далее количество заказов группы "А" начала падать и установилась к концу теста около значения ~ 3%, а количество заказов группы "B" начала рости и установилась к концу теста около значения ~ 3.4%. Абсолютное значение колебания количества заказов групп "А" и "В" небольшое: от 2.9% до 3.7%, а относительное - 1,28 раза.

# %% [markdown]
# ### Построим график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A.

# %%
mergedCumulativeConversions = cumulativeDataA[['date','conversion']].merge(cumulativeDataB[['date','conversion']],\
                                                                           left_on='date', right_on='date', how='left',\
                                                                           suffixes=['A', 'B'])

# изменим размер фигуры
plt.figure(figsize=(8, 5))

# строим графики
plt.plot(mergedCumulativeConversions['date'], mergedCumulativeConversions['conversionB']/\
         mergedCumulativeConversions['conversionA']-1,\
         label="Относительный прирост конверсии группы B относительно группы A")
plt.legend()

plt.axhline(y=0, color='black', linestyle='--')
plt.axhline(y=0.13, color='grey', linestyle='--')

# задаем масштаб осей
plt.axis(['2019-08-01', '2019-09-01', -0.2, 0.3])

plt.title('График относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A')
plt.xlabel('Дата')
plt.xticks(rotation=45)
plt.ylabel('Отношение конверсии группы В к группе А')
plt.grid();

# %% [markdown]
# Практически с начала теста группа "В" лидирует по конверсии и к 15-му августа прирост составляет ~ 21%, к концу теста фиксируется около прироста 13% относительно группы "А".

# %% [markdown]
# ### Построим точечный график количества заказов по пользователям.

# %% [markdown]
# Подсчитаем количество заказов по пользователям и выведем первые 5 строк с максимальным количеством заказов.

# %%
ordersByUsers = (orders.groupby('visitor_id', as_index=False).agg({'transaction_id': 'nunique'}))
ordersByUsers.columns = ['visitor_id', 'orders']
display(ordersByUsers.sort_values(by='orders', ascending=False).head(5))
# Out:
#       visitor_id  orders
# 1023  4256040402      11
# 591   2458001652      11
# 569   2378935119       9
# 487   2038680547       8
# 44     199603092       5

# %% [markdown]
# Построим диаграмму количества заказов по пользователям методом scatter().

# %%
# серия из чисел от 0 до количества наблюдений в ordersByUsers
x_values = pd.Series(range(0, len(ordersByUsers)))

# изменим размер фигуры
plt.figure(figsize=(8, 5))

# строим график
plt.scatter(x_values, ordersByUsers['orders'], alpha=0.4)

plt.title('График количества заказов по пользователям')
plt.xlabel('Количество наблюдений')
plt.ylabel('Количество заказов')
plt.grid();

# %% [markdown]
# Больше всего пользователей, совершивших только 1 заказ. Пользователей с 2-мя заказами уже не так много. Ещё меньше пользователей, совершивших более 2-х заказов. Их точная доля не ясна — непонятно, считать их аномалиями или нет. Для этого посчитаем 95-й и 99-й перцентили количества заказов на одного пользователя.

# %% [markdown]
# ### Посчитаем 95-й и 99-й перцентили количества заказов на пользователя. Выберем границу для определения аномальных пользователей.

# %%
print(np.percentile(ordersByUsers['orders'], [95, 99]))
# Out:
# [2. 4.]

# %% [markdown]
# Не более 5% пользователей оформляли более 2-х заказов и не более 1% пользователей заказывали более 4-х раз.
#
# В качестве границы для определения аномальных пользователей выберем пользователей, которые совершили не более 4-х заказов (это 99% всех пользователей).

# %% [markdown]
# ### Построим точечный график стоимостей заказов.

# %%
x_values = pd.Series(range(0, len(orders['revenue'])))

# изменим размер фигуры
plt.figure(figsize=(8, 5))

# строим график
plt.scatter(x_values, orders['revenue'], alpha=0.4)

plt.title('График стоимостей заказов')
plt.xlabel('Количество наблюдений')
plt.ylabel('Стоимость заказа')
plt.grid();

# %% [markdown]
# Большинсто заказов не более 100 000, также есть аномальные значения - около 200 000 и более 1 200 000.
# Построим более наглядный график для заказов до 200 000 (без выбросов).

# %%
orders_normal = orders.query('revenue < 200000')

x_values = pd.Series(range(0, len(orders_normal['revenue'])))

# изменим размер фигуры
plt.figure(figsize=(8, 5))

# строим график
plt.scatter(x_values, orders_normal['revenue'], alpha=0.4)

plt.title('График стоимостей заказов до 200 000')
plt.xlabel('Количество наблюдений')
plt.ylabel('Стоимость заказа')
plt.grid();

# %% [markdown]
# На графике видно, что стоимость остальных заказов (без выбросов) не более 100 000. Посчитаем 95-й и 99-й перцентили стоимости заказов, чтобы выбрать границу для определения аномальных заказов.

# %% [markdown]
# ### Посчитаем 95-й и 99-й перцентили стоимости заказов. Выберем границу для определения аномальных заказов.

# %%
print(np.percentile(orders['revenue'], [95, 99]))
# Out:
# [28000.  58233.2]

# %% [markdown]
# Не более чем у 5% заказов чек дороже 28 000 и не более чем у 1% заказов чек дороже - 58 233,20.
#
# В качестве границы для определения аномальных заказов, выберем заказы не дороже 58 233,20 (это 99% всех заказов).

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным.

# %% [markdown]
# Рассчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным - без удаления аномальных пользователей. Сформулируем гипотезы и подготовим данные.
#
# **Нулевая гипотеза**: различий в среднем количестве заказов между группами нет.
# **Альтернативная гипотеза**: различия в среднем количестве заказов между группами есть.
#
# Подготовим данные для проверки гипотез.

# %%
visitorsADaily = visitors[visitors['group'] == 'A'][['date', 'visitors']]
visitorsADaily.columns = ['date', 'visitorsPerDateA']

visitorsACummulative = visitorsADaily.apply(
    lambda x: visitorsADaily[visitorsADaily['date'] <= x['date']].agg(
        {'date': 'max', 'visitorsPerDateA': 'sum'}
    ),
    axis=1
)
visitorsACummulative.columns = ['date', 'visitorsCummulativeA']

visitorsBDaily = visitors[visitors['group'] == 'B'][['date', 'visitors']]
visitorsBDaily.columns = ['date', 'visitorsPerDateB']

visitorsBCummulative = visitorsBDaily.apply(
    lambda x: visitorsBDaily[visitorsBDaily['date'] <= x['date']].agg(
        {'date': 'max', 'visitorsPerDateB': 'sum'}
    ),
    axis=1
)
visitorsBCummulative.columns = ['date', 'visitorsCummulativeB']

ordersADaily = (
    orders[orders['group'] == 'A'][['date', 'transaction_id', 'visitor_id', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transaction_id': pd.Series.nunique, 'revenue': 'sum'})
)
ordersADaily.columns = ['date', 'ordersPerDateA', 'revenuePerDateA']

ordersACummulative = ordersADaily.apply(
    lambda x: ordersADaily[ordersADaily['date'] <= x['date']].agg(
        {'date': 'max', 'ordersPerDateA': 'sum', 'revenuePerDateA': 'sum'}
    ),
    axis=1
).sort_values(by=['date'])
ordersACummulative.columns = [
    'date',
    'ordersCummulativeA',
    'revenueCummulativeA',
]

ordersBDaily = (
    orders[orders['group'] == 'B'][['date', 'transaction_id', 'visitor_id', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transaction_id': pd.Series.nunique, 'revenue': 'sum'})
)
ordersBDaily.columns = ['date', 'ordersPerDateB', 'revenuePerDateB']

ordersBCummulative = ordersBDaily.apply(
    lambda x: ordersBDaily[ordersBDaily['date'] <= x['date']].agg(
        {'date': 'max', 'ordersPerDateB': 'sum', 'revenuePerDateB': 'sum'}
    ),
    axis=1
).sort_values(by=['date'])
ordersBCummulative.columns = [
    'date',
    'ordersCummulativeB',
    'revenueCummulativeB',
]

data = (
    ordersADaily.merge(
        ordersBDaily, left_on='date', right_on='date', how='left'
    )
    .merge(ordersACummulative, left_on='date', right_on='date', how='left')
    .merge(ordersBCummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsADaily, left_on='date', right_on='date', how='left')
    .merge(visitorsBDaily, left_on='date', right_on='date', how='left')
    .merge(visitorsACummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsBCummulative, left_on='date', right_on='date', how='left')
)

data.head(5)
# Out:
#         date  ordersPerDateA  revenuePerDateA  ordersPerDateB  \
# 0 2019-08-01              24           148579              21
# 1 2019-08-02              20            93822              24
# 2 2019-08-03              24           112473              16
# 3 2019-08-04              16            70825              17
# 4 2019-08-05              25           124218              23
#
#    revenuePerDateB  ordersCummulativeA  revenueCummulativeA  \
# 0           101217                  24               148579
# 1           165531                  44               242401
# 2           114248                  68               354874
# 3           108571                  84               425699
# 4            92428                 109               549917
#
#    ordersCummulativeB  revenueCummulativeB  visitorsPerDateA  \
# 0                  21               101217               719
# 1                  45               266748               619
# ...

# %% [markdown]
# Посчитаем статистическую значимость различия в среднем количестве заказов между группами.
# Создадим переменные ***ordersByUsersA*** и ***ordersByUsersB*** со столбцами ***['visitor_id', 'orders']***. В них для пользователей, которые заказывали хотя бы 1 раз, укажем число совершённых заказов.

# %%
ordersByUsersA = (
    orders[orders['group'] == 'A']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)
ordersByUsersA.columns = ['visitor_id', 'orders']

ordersByUsersB = (
    orders[orders['group'] == 'B']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)
ordersByUsersB.columns = ['visitor_id', 'orders']

# %% [markdown]
# Объявим переменные ***sampleA*** и ***sampleB***, в которых пользователям из разных групп будет соответствовать количество заказов. Тем, кто ничего не заказал, будут соответствовать нули. Это нужно, чтобы подготовить выборки к проверке критерием Манна-Уитни.

# %%
sampleA = pd.concat(
    [
        ordersByUsersA['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sampleB = pd.concat(
    [
        ordersByUsersB['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

print('alpha:', 0.05)
print('p-value:', "{0:.5f}".format(stats.mannwhitneyu(sampleA, sampleB)[1]))
print('Относительный прирост среднего числа заказов группы "B" к группе "А":',\
      "{0:.3f}".format((data['ordersPerDateB'].sum()/data['visitorsPerDateB'].sum())\
                       /(data['ordersPerDateA'].sum()/data['visitorsPerDateA'].sum())-1))
# Out:
# alpha: 0.05
# p-value: 0.01679
# Относительный прирост среднего числа заказов группы "B" к группе "А": 0.138

# %% [markdown]
# ***Вывод***: По «сырым» данным различие в среднем количестве заказов на посетителя между группами "A" и "B" есть. Значение p-value: 0.01679 < критического уровня статистической значимости alpha: 0.05, отвергаем нулевую гипотезу. Относительный выигрыш группы "B" равен 13.8%.

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным.

# %% [markdown]
# Рассчитаем статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным - без удаления аномальных пользователей. Сформулируем гипотезы и подготовим данные.
#
# Сформулируем гипотезы.
#
# **Нулевая гипотеза**: различий в среднем чеке заказа между группами нет.
# **Альтернативная гипотеза**: различия в среднем чеке заказа между группами есть.

# %% [markdown]
# Чтобы рассчитать статистическую значимость различий в среднем чеке заказа, передадим критерию ***mannwhitneyu()*** данные о выручке с заказов. А также найдём относительные различия в среднем чеке между группами.

# %%
print('alpha:', 0.05)
print('p-value:', '{0:.3f}'.format(stats.mannwhitneyu(orders[orders['group']=='A']['revenue'],\
                                                      orders[orders['group']=='B']['revenue'])[1]))
print('Относительный прирост среднего чека заказа группы "B" к группе "А":',\
      '{0:.3f}'.format(orders[orders['group']=='B']['revenue'].mean()/orders[orders['group']=='A']['revenue'].mean()-1))
# Out:
# alpha: 0.05
# p-value: 0.729
# Относительный прирост среднего чека заказа группы "B" к группе "А": 0.259

# %% [markdown]
# ***Вывод***: По «сырым» данным различий в среднем чеке заказа между группами "A" и "B" нет. Значение p-value: 0.729 > критического уровня статистической значимости alpha: 0.05, не получилось отвергнуть нулевую гипотезу. Наблюдаемое превышение среднего чека группы "В" на 25.9% не является значимым, получено случайно.

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным.

# %% [markdown]
# Рассчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным - с удалением аномальных пользователей. Сформулируем гипотезы и подготовим данные.
#
# **Нулевая гипотеза**: различий в среднем количестве заказов между группами нет.
# **Альтернативная гипотеза**: различия в среднем количестве заказов между группами есть.
#
# Подготовим данные для проверки гипотез.
#
# Ранее в качестве границы для определения аномальных пользователей мы выбрали пользователей, которые совершили не более 4-х заказов или совершили заказ не дороже 58 233,20. Т.е. аномальными пользователями будем считать пользователей, кторые сеовершили более 4-х заказов или заказ дороже 58 233,20. Так мы уберём 1% пользователей с наибольшим числом заказов и 1% пользователей с дорогими заказами.
#
# Сделаем срезы пользователей с числом заказов больше 4 — ***usersWithManyOrders*** и пользователей, совершивших заказы дороже 58 233,20 — ***usersWithExpensiveOrders***. Объединим их в таблице ***abnormalUsers*** и выведем количество аномальных пользователей.

# %%
usersWithManyOrders = pd.concat(
    [
        ordersByUsersA[ordersByUsersA['orders'] > np.percentile(ordersByUsers['orders'], [99])[0]]['visitor_id'],
        ordersByUsersB[ordersByUsersB['orders'] > np.percentile(ordersByUsers['orders'], [99])[0]]['visitor_id'],
    ],
    axis=0
)
usersWithExpensiveOrders = orders[orders['revenue'] > np.percentile(orders['revenue'], [99])[0]]['visitor_id']
abnormalUsers = (
    pd.concat([usersWithManyOrders, usersWithExpensiveOrders], axis=0)
    .drop_duplicates()
    .sort_values()
)
print('Всего', abnormalUsers.shape[0], 'аномальных пользователей.')
# Out:
# Всего 15 аномальных пользователей.

# %% [markdown]
# Узнаем, как их действия повлияли на результаты теста. Посчитаем статистическую значимость различий в среднем количестве заказов между группами теста по очищенным данным. Сначала подготовим выборки количества заказов по пользователям по группам теста.

# %%
sampleAFiltered = pd.concat(
    [
        ordersByUsersA[
            np.logical_not(ordersByUsersA['visitor_id'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0
)

sampleBFiltered = pd.concat(
    [
        ordersByUsersB[
            np.logical_not(ordersByUsersB['visitor_id'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0
)

# %% [markdown]
# Применим статистический критерий Манна-Уитни к полученным выборкам.

# %%
print('alpha:', 0.05)
print('p-value:', '{0:.3f}'.format(stats.mannwhitneyu(sampleAFiltered, sampleBFiltered)[1]))
print('Относительный прирост среднего числа заказов группы "B" к группе "А":',\
      '{0:.3f}'.format(sampleBFiltered.mean()/sampleAFiltered.mean()-1))
# Out:
# alpha: 0.05
# p-value: 0.014
# Относительный прирост среднего числа заказов группы "B" к группе "А": 0.153

# %% [markdown]
# ***Вывод***: Результаты по среднему количеству заказов практически не изменились. По «очищенным» данным различие в среднем количестве заказов на посетителя между группами "A" и "B" есть. Значение p-value: 0.014 < критического уровня статистической значимости alpha: 0.05, отвергаем нулевую гипотезу. Относительный выигрыш группы "B" равен 15.3%, выше чем по "сырым" данным - 13.8%.

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным.

# %% [markdown]
# Рассчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным - с удалением аномальных пользователей. Сформулируем гипотезы и подготовим данные.
#
# Сформулируем гипотезы.
#
# **Нулевая гипотеза**: различий в среднем чеке заказа между группами нет.
# **Альтернативная гипотеза**: различия в среднем чеке заказа между группами есть.
#
# Чтобы рассчитать статистическую значимость различий в среднем чеке заказа, передадим критерию ***mannwhitneyu()*** данные о выручке с заказов. А также найдём относительные различия в среднем чеке между группами.

# %%
print('alpha:', 0.05)
print(
    'p-value:', 
    '{0:.3f}'.format(
        stats.mannwhitneyu(
            orders[
                np.logical_and(
                    orders['group'] == 'A',
                    np.logical_not(orders['visitor_id'].isin(abnormalUsers)),
                )
            ]['revenue'],
            orders[
                np.logical_and(
                    orders['group'] == 'B',
                    np.logical_not(orders['visitor_id'].isin(abnormalUsers)),
                )
            ]['revenue'],
        )[1]
    )
)

print('Относительный прирост среднего чека заказа группы "B" к группе "А":', 
    "{0:.3f}".format(
        orders[
            np.logical_and(
                orders['group'] == 'B',
                np.logical_not(orders['visitor_id'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        / orders[
            np.logical_and(
                orders['group'] == 'A',
                np.logical_not(orders['visitor_id'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        - 1
    )
)
# Out:
# alpha: 0.05
# p-value: 0.851
# Относительный прирост среднего чека заказа группы "B" к группе "А": -0.006

# %% [markdown]
# ***Вывод***: По «очищенным» данным различий в среднем чеке заказа между группами "A" и "B" нет. Значение p-value: 0.851 > критического уровня статистической значимости alpha: 0.05, не получилось отвергнуть нулевую гипотезу. P-value увеличился, но и разница между сегментами изменилась с 25.9% до -0.6%. Относительный проигрыш группы "B" над группой "А" равен -0.6%.

# %% [markdown]
# ### Примем решение по результатам теста и объясним его.

# %% [markdown]
# Для принятия решения по результатам теста примем во внимание имеющиеся факты:
# * Есть статистически значимое различие по среднему количеству заказов между группами по «сырым» и по «очищенным» данным (после фильтрации аномалий).
# * Нет статистически значимого различия по среднему чеку между группами ни по «сырым», ни по «очищенным» данным.
# * График различия конверсии между группами сообщает, что результаты группы "B" лучше группы "A" примерно на 13%.
# * График различия среднего чека говорит о том, что результаты группы "B" лучше группы "A" примерно на 26%.
#
# И по "очищенным" и по "сырым" данным различие в среднем количестве заказов на посетителя между группами "A" и "B" есть, относительный выигрыш группы "B" над "A" равен 15.3% по "очищенным" и 13.8% по "сырым" данным.
# А вот различия по среднему чеку между группами ни по "сырым", ни по "очищенным" данным нет, но средний чек по "очищенным" данным немного меньше у группы "В" на -0.6%, хотя по "сырым" данным он был больше у группы "В" примерно на 26%.
#
# **Вывод: Исходя из обнаруженных фактов, следует остановить тест, зафиксировать победу группы "В".**

# %% [markdown]
# ## Выводы.

# %% [markdown]
# По 1-й части (приоритизация гипотез):
# * Приоритизация гипотез методами "ICE" и "RICE" даёт немного разные списки перспективных гипотез. Наиболее перспективная гипотеза по методу "RICE" с учётом охвата максимального количества пользователей - гипотеза №7: "Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок".
#
# По 2-й части (анализ результатов А/В-теста):
# * По "очищенным" и по "сырым" данным есть различие в среднем количестве заказов на посетителя между группами "A" и "B", относительный выигрыш группы "B" над "A" по "очищенным" данным - 15.3%.
# * Различия по среднему чеку между группами "А" и "В" нет, средний чек по "очищенным" данным меньше у группы "В" на -0.6%.
# Исходя из обнаруженных фактов, следует остановить тест, зафиксировать победу группы "В".
